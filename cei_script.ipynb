# %% [markdown]
# <a href="https://colab.research.google.com/github/fernandofsilva/brazilian-taxes-calculator/blob/master/cei_script.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %% [markdown]
# # Abril

# %%
archive = 'drive/My Drive/Colab Notebooks/cei/InfoCEI_Abril.xls'

# %%
inicio_df_rowindex = 'RESUMO DOS SALDOS EM  30/04/2020'
final_df_rowindex = 'VALORIZAÇÃO EM REAIS'
arquivo_cei_custodia = pd.read_excel(archive, usecols=('F:BE'), index_col=0) # columns "F:BE" will be the same always ?
# Out:
# WARNING *** file size (82596) not 512 + multiple of sector size (512)

# %%
arquivo_cei_custodia = arquivo_cei_custodia.loc[inicio_df_rowindex:final_df_rowindex]
arquivo_cei_custodia
# Out:
#                                   Unnamed: 6 Unnamed: 7  ...  Unnamed: 55  Unnamed: 56
# RESUMO DOS SALDOS EM  30/04/2020         NaN        NaN  ...          NaN          NaN
# Ativos em Custódia                       NaN        NaN  ...          NaN          NaN
# Ativo                                    NaN        NaN  ...          NaN        Valor
# BANCO INTER                              NaN        NaN  ...          NaN      1098.25
# BBSEGURIDADE                             NaN        NaN  ...          NaN        262.6
# BRASKEM                                  NaN        NaN  ...          NaN        637.2
# CVC BRASIL                               NaN        NaN  ...          NaN       914.55
# ENERGIAS BR                              NaN        NaN  ...          NaN        169.3
# EVEN                                     NaN        NaN  ...          NaN        480.9
# FII BC FFII                              NaN        NaN  ...          NaN       939.84
# ...

# %%
arquivo_cei_custodia.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_custodia
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                  Unnamed: 20  ... Unnamed: 56
# RESUMO DOS SALDOS EM  30/04/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                               Especif.  ...       Valor
# BANCO INTER                       PN      N2  ...     1098.25
# BBSEGURIDADE                      ON      NM  ...       262.6
# BRASKEM                           PNA     N1  ...       637.2
# CVC BRASIL                        ON      NM  ...      914.55
# ENERGIAS BR                       ON      NM  ...       169.3
# EVEN                              ON      NM  ...       480.9
# ...

# %% [markdown]
# ## Negociação

# %%
inicio_df_rowindex = 'INFORMAÇÕES DE NEGOCIAÇÃO DE ATIVOS'
arquivo_cei_negociacao = pd.read_excel(archive, usecols=('D:BC'), index_col=0, parse_dates=['Unnamed: 10']) # columns 'D:BC' will be the same always ?
arquivo_cei_negociacao
# Out:
# WARNING *** file size (82596) not 512 + multiple of sector size (512)
#                                             Unnamed: 4  ... Unnamed: 54
# NaN                                                NaN  ...         NaN
# NaN                                                NaN  ...         NaN
# NaN                                                NaN  ...         NaN
# NaN                                                NaN  ...         NaN
# NaN                                                NaN  ...         NaN
# ..                                                 ...  ...         ...
# NaN  (B) POP - Proteção do Investimento com Partici...  ...         NaN
# NaN                                                NaN  ...         NaN
# NaN                                  (N1) Cia. Nível 1  ...         NaN
# NaN                                                NaN  ...         NaN
# NaN                             (NM) Cia. Novo Mercado  ...         NaN
#
# [194 rows x 51 columns]

# %%
#fail, tried exclude all indexes NaN
#for i in range(0,len(arquivo_cei_negociacao)):
#  linha_verificar = arquivo_cei_negociacao.iloc[i:(i+1),:]
#  if linha_verificar.index[0] == 'nan':
#    arquivo_cei_negociacao.drop(linha_verificar, inplace=True)
#  else:
#    pass

# %%
arquivo_cei_negociacao = arquivo_cei_negociacao.loc[inicio_df_rowindex:]
arquivo_cei_negociacao
# Out:
#                                                                             Unnamed: 4  ... Unnamed: 54
# INFORMAÇÕES DE NEGOCIAÇÃO DE ATIVOS                                                NaN  ...         NaN
# NaN                                                                                NaN  ...         NaN
# Cód                                                                                NaN  ...     Posição
# BBSE3F                                                                             NaN  ...    COMPRADA
# EVEN3F                                                                             NaN  ...    COMPRADA
# ITSA4F                                                                             NaN  ...    COMPRADA
# IVVB11F                                                                            NaN  ...     VENDIDA
# LPSB3F                                                                             NaN  ...    COMPRADA
# ...

# %%
arquivo_cei_negociacao.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_negociacao
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#                                                                             Unnamed: 4  ... Unnamed: 54
# INFORMAÇÕES DE NEGOCIAÇÃO DE ATIVOS                                                NaN  ...         NaN
# NaN                                                                                NaN  ...         NaN
# Cód                                                                                NaN  ...     Posição
# BBSE3F                                                                             NaN  ...    COMPRADA
# EVEN3F                                                                             NaN  ...    COMPRADA
# ...

# %% [markdown]
# # Março

# %%
inicio_df_rowindex = 'RESUMO DOS SALDOS EM  31/03/2020'
final_df_rowindex = 'VALORIZAÇÃO EM REAIS'
arquivo_cei_custodia = pd.read_excel('drive/My Drive/Colab Notebooks/cei/InfoCEI_Marco.xls', usecols=('F:BE'), index_col=0)
# Out:
# WARNING *** file size (92509) not 512 + multiple of sector size (512)

# %%
arquivo_cei_custodia = arquivo_cei_custodia.loc[inicio_df_rowindex:final_df_rowindex]
arquivo_cei_custodia
# Out:
#                                   Unnamed: 6 Unnamed: 7  ...  Unnamed: 55  Unnamed: 56
# RESUMO DOS SALDOS EM  31/03/2020         NaN        NaN  ...          NaN          NaN
# Ativos em Custódia                       NaN        NaN  ...          NaN          NaN
# Ativo                                    NaN        NaN  ...          NaN        Valor
# BANCO INTER                              NaN        NaN  ...          NaN       160.05
# BRASKEM                                  NaN        NaN  ...          NaN        530.4
# CVC BRASIL                               NaN        NaN  ...          NaN        768.3
# ENERGIAS BR                              NaN        NaN  ...          NaN        165.5
# EVEN                                     NaN        NaN  ...          NaN          195
# FII BC FFII                              NaN        NaN  ...          NaN       863.28
# FII BC FUND                              NaN        NaN  ...          NaN       358.32
# ...

# %%
arquivo_cei_custodia.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_custodia
# Out:
#                                  Unnamed: 20  ... Unnamed: 56
# RESUMO DOS SALDOS EM  31/03/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                               Especif.  ...       Valor
# BANCO INTER                       PN      N2  ...      160.05
# BRASKEM                           PNA     N1  ...       530.4
# CVC BRASIL                        ON      NM  ...       768.3
# ENERGIAS BR                       ON      NM  ...       165.5
# EVEN                              ON      NM  ...         195
# FII BC FFII                       CI          ...      863.28
# FII BC FUND                       CI          ...      358.32
# FII HSI MALL                      CI          ...      425.15
# FII KINEA                         CI          ...       771.5
# FII MAXI REN                      CI          ...       616.2
# FII XP LOG                        CI          ...         535
# ...

# %% [markdown]
# # Fevereiro

# %%
inicio_df_rowindex = 'RESUMO DOS SALDOS EM  28/02/2020'
final_df_rowindex = 'VALORIZAÇÃO EM REAIS'
arquivo_cei_custodia = pd.read_excel('drive/My Drive/Colab Notebooks/cei/InfoCEI_Fevereiro.xls', usecols=('F:BE'), index_col=0)
# Out:
# WARNING *** file size (61617) not 512 + multiple of sector size (512)

# %%
arquivo_cei_custodia = arquivo_cei_custodia.loc[inicio_df_rowindex:final_df_rowindex]
arquivo_cei_custodia
# Out:
#                                   Unnamed: 6  ... Unnamed: 56
# RESUMO DOS SALDOS EM  28/02/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                                    NaN  ...         NaN
# BANCO INTER                              NaN  ...         NaN
# BRASKEM                                  NaN  ...         NaN
# CVC BRASIL                               NaN  ...         NaN
# ENERGIAS BR                              NaN  ...         NaN
# EVEN                                     NaN  ...         NaN
# FII BC FFII                              NaN  ...         NaN
# FII BC FUND                              NaN  ...         NaN
# FII HSI MALL                             NaN  ...         NaN
# FII KINEA                                NaN  ...         NaN
# FII MAXI REN                             NaN  ...         NaN
# FII XP LOG                               NaN  ...         NaN
# ...

# %%
arquivo_cei_custodia.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_custodia
# Out:
#                                  Unnamed: 20  ... Unnamed: 54
# RESUMO DOS SALDOS EM  28/02/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                               Especif.  ...       Valor
# BANCO INTER                       PN      N2  ...      219.15
# BRASKEM                           PNA     N1  ...       399.6
# CVC BRASIL                        ON      NM  ...      281.82
# ENERGIAS BR                       ON      NM  ...       60.03
# EVEN                              ON      NM  ...      208.95
# FII BC FFII                       CI          ...      491.25
# FII BC FUND                       CI          ...      432.08
# FII HSI MALL                      CI          ...      575.05
# FII KINEA                         CI          ...       853.1
# FII MAXI REN                      CI          ...       111.7
# FII XP LOG                        CI          ...      653.75
# ...

# %% [markdown]
# # Janeiro

# %%
inicio_df_rowindex = 'RESUMO DOS SALDOS EM  31/01/2020'
final_df_rowindex = 'VALORIZAÇÃO EM REAIS'
arquivo_cei_custodia = pd.read_excel('drive/My Drive/Colab Notebooks/cei/InfoCEI_Janeiro.xls', usecols=('F:BE'), index_col=0)
# Out:
# WARNING *** file size (109201) not 512 + multiple of sector size (512)

# %%
arquivo_cei_custodia = arquivo_cei_custodia.loc[inicio_df_rowindex:final_df_rowindex]
arquivo_cei_custodia
# Out:
#                                   Unnamed: 6  ... Unnamed: 54
# RESUMO DOS SALDOS EM  31/01/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                                    NaN  ...         NaN
# BANCO INTER                              NaN  ...         NaN
# BRASKEM                                  NaN  ...         NaN
# CVC BRASIL                               NaN  ...         NaN
# ENERGIAS BR                              NaN  ...         NaN
# EVEN                                     NaN  ...         NaN
# FII BC FFII                              NaN  ...         NaN
# FII BC FFII                              NaN  ...         NaN
# FII BC FUND                              NaN  ...         NaN
# FII HSI MALL                             NaN  ...         NaN
# FII KINEA                                NaN  ...         NaN
# FII MAXI REN                             NaN  ...         NaN
# ...

# %%
arquivo_cei_custodia.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_custodia
# Out:
#                                  Unnamed: 19  ... Unnamed: 51
# RESUMO DOS SALDOS EM  31/01/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                               Especif.  ...       Valor
# BANCO INTER                       PN      N2  ...      242.25
# BRASKEM                           PNA     N1  ...       479.1
# CVC BRASIL                        ON      NM  ...       394.9
# ENERGIAS BR                       ON      NM  ...       66.63
# EVEN                              ON      NM  ...      251.85
# FII BC FFII                       CI  ES      ...      506.55
# FII BC FFII                       DIR         ...       15.02
# FII BC FUND                       CI          ...      457.56
# FII HSI MALL                      CI          ...      608.65
# FII KINEA                         CI          ...      906.85
# FII MAXI REN                      CI  ES      ...       117.1
# ...

# %% [markdown]
# # Abril - Fefo

# %%
import pandas as pd
archive = 'drive/My Drive/Colab Notebooks/cei/InfoCEI_Abril_F.xls'

# %%
inicio_df_rowindex = 'RESUMO DOS SALDOS EM  30/04/2020'
final_df_rowindex = 'VALORIZAÇÃO EM REAIS'
arquivo_cei_custodia = pd.read_excel(archive, usecols=('F:BE'), index_col=0)
# Out:
# WARNING *** file size (75834) not 512 + multiple of sector size (512)

# %%
arquivo_cei_custodia = arquivo_cei_custodia.loc[inicio_df_rowindex:final_df_rowindex]
arquivo_cei_custodia
# Out:
#                                   Unnamed: 6  ... Unnamed: 56
# RESUMO DOS SALDOS EM  30/04/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                                    NaN  ...         NaN
# B3                                       NaN  ...         NaN
# BBSEGURIDADE                             NaN  ...         NaN
# BRASIL                                   NaN  ...         NaN
# BRASKEM                                  NaN  ...         NaN
# COELCE                                   NaN  ...         NaN
# COSAN LOG                                NaN  ...         NaN
# ENERGIAS BR                              NaN  ...         NaN
# FII BB PRGII                             NaN  ...         NaN
# FII BC FUND                              NaN  ...         NaN
# FII BEES CRI                             NaN  ...         NaN
# FII BTLG                                 NaN  ...         NaN
# ...

# %%
arquivo_cei_custodia.dropna(axis='columns', how='all', inplace=True)
arquivo_cei_custodia
# Out:
#                                  Unnamed: 20  ... Unnamed: 54
# RESUMO DOS SALDOS EM  30/04/2020         NaN  ...         NaN
# Ativos em Custódia                       NaN  ...         NaN
# Ativo                               Especif.  ...       Valor
# B3                                ON      NM  ...        3870
# BBSEGURIDADE                      ON      NM  ...       10504
# BRASIL                            ON      NM  ...       11332
# BRASKEM                           PNA     N1  ...       16992
# COELCE                            PNA ED      ...        4750
# COSAN LOG                         ON      NM  ...        7730
# ENERGIAS BR                       ON      NM  ...       10158
# FII BB PRGII                      CI          ...      4120.2
# FII BC FUND                       CI          ...     3803.57
# FII BEES CRI                      CI          ...      4213.6
# FII BTLG                          CI          ...     3554.07
# ...
